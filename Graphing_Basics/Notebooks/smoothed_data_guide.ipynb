# %%
# Excel Interpreter Library
import pandas as pd

# Visualization Library
import matplotlib.pyplot as plt

#Reading the Excel File
raw_data = pd.read_excel(
    "NAME OF EXCEL FILE (or use the path)"
)

#Making the index the time and date
raw_data = raw_data.set_index("Time and Date")

#Printing the Data in the interactive window
print(raw_data)

#Applying a Moving Average to smooth out the data points
smoothed_data = raw_data.rolling(window='XX', center=True).mean()
#window controls the amount of points it is averaging - selec value for window and replace 'XX'



#What parameters we are plotting
plt.plot (smoothed_data['X-AXIS TITLE'], smoothed_data['Y-AXIS TITLE'])
plt.xlabel('X-AXIS') #x axis label
plt.ylabel('Y-AXIS') #yaxis label
plt.title('TITLE') #title label

#show the plot
plt.show
# Out:
#                      Temperature in C
# Time and Date
# 2022-05-01 00:00:00            13.153
# 2022-05-01 00:05:00            13.153
# 2022-05-01 00:10:00            13.153
# 2022-05-01 00:15:00            13.153
# 2022-05-01 00:20:00            13.153
# ...                               ...
# 2022-06-09 14:20:00            13.146
# 2022-06-09 14:25:00            13.146
# 2022-06-09 14:30:00            13.146
# 2022-06-09 14:35:00            13.146
# 2022-06-09 14:40:00            13.146
#
# [11397 rows x 1 columns]
# <function matplotlib.pyplot.show(close=None, block=None)>
